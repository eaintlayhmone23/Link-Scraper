# %% [markdown]
# ### Scraper for <a href="https://www.eiyokentei.com/category/column/"> Eiyokentei </a> website

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import os
import requests

# %%
def get_chrome_Driver():
    driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
    return driver

def get_soup(URL):
    r = requests.get(URL)
    if r:
        driver = get_chrome_Driver()
        driver.get(URL)
        htmlContent = driver.page_source
        soup =  BeautifulSoup(htmlContent, 'html.parser')
        driver.close()
        return soup
    else:
        print("Error Fetching Soup, Scraping Ended")
        return False

def get_link_from_soup(soup):
    ul = soup.findAll('ul',{'class':'column_article__list column_article__pager js-new js-pager'})[0]
    wanted_lis= ul.findAll('li',{'class':'js-pager-list'})
    link_list = []

    for li in wanted_lis:
        link=li.find('div',{'class':'column_article__box--wrap'}).div.a
        link ='https://www.nttpc.co.jp/'+ str(link['href'])
        print(link)
        link_list.append(link)
        
    return link_list


def save_link_as_txt(link_list):
    file_path = "links/nttpc.txt"
    # if file exist, get its content, merge to existing set and then overwrite
    if os.path.isfile(file_path):
        with open(file_path, 'r+', encoding="utf-8") as file:
            # get existing links in file
            old_links = set(file.readlines())
            # remove duplicates 
            link_list = link_list - old_links
            file.seek(0)
            for i in link_list:
                file.write(i+"\n")
            file.truncate()
    else: # if not, make new file
        os.makedirs(os.path.dirname(file_path), exist_ok=True)
        with open(file_path, "w", encoding="utf-8") as file:
            for i in link_list:
                file.write(i+"\n")
    print(f"Links Saved in {file_path}")
    return True

# %%
all_links = set()
for i in range(1,8):
    if i == 1:
        URL = 'https://www.nttpc.co.jp/column/tag/network/'
    else:
        URL = f"https://www.nttpc.co.jp/column/tag/network/?page={i}"

    soup = get_soup(URL)
    if soup:
        current_links = get_link_from_soup(soup)
        if len(current_links) > 0: # continue until no tags are found 
            all_links.update(current_links)
        else: # if tags we want are not found
            break
    else: # if encountered HTML error such as 404
        break

save_link_as_txt(all_links)
# Out:
# https://www.nttpc.co.jp//column/network/whats_vpn.html
# https://www.nttpc.co.jp//column/network/whats_ip.html
# https://www.nttpc.co.jp//column/network/whats_bcp.html
# https://www.nttpc.co.jp//column/security/hacker.html
# https://www.nttpc.co.jp//column/security/vpn_security_risk.html
# https://www.nttpc.co.jp//column/network/cloudwan_5g.html
# https://www.nttpc.co.jp//column/network/leasedline.html
# https://www.nttpc.co.jp//column/network/internal_network.html
# https://www.nttpc.co.jp//column/data_center/data_center.html
# https://www.nttpc.co.jp//column/security/bof.html
# https://www.nttpc.co.jp//column/security/exploit.html
# https://www.nttpc.co.jp//column/security/epp-edr.html
# https://www.nttpc.co.jp//column/security/information_leakage_measures.html
# https://www.nttpc.co.jp//column/security/phishing-site.html
# https://www.nttpc.co.jp//column/network/fixed_ip.html
# https://www.nttpc.co.jp//column/network/pppoe_ipoe.html
# https://www.nttpc.co.jp//column/security/os-command_injection.html
# https://www.nttpc.co.jp//column/data_center/collocation.html
# https://www.nttpc.co.jp//column/security/ids-ips.html
# https://www.nttpc.co.jp//column/security/firewall.html
# https://www.nttpc.co.jp//column/security/sql_injection.html
# https://www.nttpc.co.jp//column/network/sase.html
# https://www.nttpc.co.jp//column/network/zero_trust.html
# https://www.nttpc.co.jp//column/security/cross_site_scripting.html
# https://www.nttpc.co.jp//column/security/waf.html
# https://www.nttpc.co.jp//column/security/cyber_attack.html
# https://www.nttpc.co.jp//column/security/security_measures.html
# https://www.nttpc.co.jp//column/security/unauthorized_access.html
# https://www.nttpc.co.jp//column/security/ransomware_defendmethod.html
# https://www.nttpc.co.jp//column/security/ransomware.html
# https://www.nttpc.co.jp//column/security/cloud_security.html
# https://www.nttpc.co.jp//column/security/malware.html
# https://www.nttpc.co.jp//column/security/vpn_security.html
# https://www.nttpc.co.jp//column/network/vpn_service.html
# https://www.nttpc.co.jp//column/network/ip_vpn.html
# https://www.nttpc.co.jp//column/network/bcp_measures.html
# https://www.nttpc.co.jp//column/telework/remote_access.html
# https://www.nttpc.co.jp//column/telework/sdwan_sdn.html
# https://www.nttpc.co.jp//column/network/whats_convergence.html
# https://www.nttpc.co.jp//column/network/o365_sdwan.html
# https://www.nttpc.co.jp//column/network/network_design.html
# https://www.nttpc.co.jp//column/network/whats_it_infrastructure.html
# https://www.nttpc.co.jp//column/network/whats_vpn.html
# https://www.nttpc.co.jp//column/network/whats_ip.html
# https://www.nttpc.co.jp//column/network/whats_bcp.html
# https://www.nttpc.co.jp//column/security/hacker.html
# https://www.nttpc.co.jp//column/security/vpn_security_risk.html
# https://www.nttpc.co.jp//column/network/cloudwan_5g.html
# https://www.nttpc.co.jp//column/network/leasedline.html
# https://www.nttpc.co.jp//column/network/internal_network.html
# https://www.nttpc.co.jp//column/data_center/data_center.html
# https://www.nttpc.co.jp//column/security/bof.html
# https://www.nttpc.co.jp//column/security/exploit.html
# https://www.nttpc.co.jp//column/security/epp-edr.html
# https://www.nttpc.co.jp//column/security/information_leakage_measures.html
# https://www.nttpc.co.jp//column/security/phishing-site.html
# https://www.nttpc.co.jp//column/network/fixed_ip.html
# https://www.nttpc.co.jp//column/network/pppoe_ipoe.html
# https://www.nttpc.co.jp//column/security/os-command_injection.html
# https://www.nttpc.co.jp//column/data_center/collocation.html
# https://www.nttpc.co.jp//column/security/ids-ips.html
# https://www.nttpc.co.jp//column/security/firewall.html
# https://www.nttpc.co.jp//column/security/sql_injection.html
# https://www.nttpc.co.jp//column/network/sase.html
# https://www.nttpc.co.jp//column/network/zero_trust.html
# https://www.nttpc.co.jp//column/security/cross_site_scripting.html
# https://www.nttpc.co.jp//column/security/waf.html
# https://www.nttpc.co.jp//column/security/cyber_attack.html
# https://www.nttpc.co.jp//column/security/security_measures.html
# https://www.nttpc.co.jp//column/security/unauthorized_access.html
# https://www.nttpc.co.jp//column/security/ransomware_defendmethod.html
# https://www.nttpc.co.jp//column/security/ransomware.html
# https://www.nttpc.co.jp//column/security/cloud_security.html
# https://www.nttpc.co.jp//column/security/malware.html
# https://www.nttpc.co.jp//column/security/vpn_security.html
# https://www.nttpc.co.jp//column/network/vpn_service.html
# https://www.nttpc.co.jp//column/network/ip_vpn.html
# https://www.nttpc.co.jp//column/network/bcp_measures.html
# https://www.nttpc.co.jp//column/telework/remote_access.html
# https://www.nttpc.co.jp//column/telework/sdwan_sdn.html
# https://www.nttpc.co.jp//column/network/whats_convergence.html
# https://www.nttpc.co.jp//column/network/o365_sdwan.html
# https://www.nttpc.co.jp//column/network/network_design.html
# https://www.nttpc.co.jp//column/network/whats_it_infrastructure.html
# https://www.nttpc.co.jp//column/network/whats_vpn.html
# https://www.nttpc.co.jp//column/network/whats_ip.html
# https://www.nttpc.co.jp//column/network/whats_bcp.html
# https://www.nttpc.co.jp//column/security/hacker.html
# https://www.nttpc.co.jp//column/security/vpn_security_risk.html
# https://www.nttpc.co.jp//column/network/cloudwan_5g.html
# https://www.nttpc.co.jp//column/network/leasedline.html
# https://www.nttpc.co.jp//column/network/internal_network.html
# https://www.nttpc.co.jp//column/data_center/data_center.html
# https://www.nttpc.co.jp//column/security/bof.html
# https://www.nttpc.co.jp//column/security/exploit.html
# https://www.nttpc.co.jp//column/security/epp-edr.html
# https://www.nttpc.co.jp//column/security/information_leakage_measures.html
# https://www.nttpc.co.jp//column/security/phishing-site.html
# https://www.nttpc.co.jp//column/network/fixed_ip.html
# https://www.nttpc.co.jp//column/network/pppoe_ipoe.html
# https://www.nttpc.co.jp//column/security/os-command_injection.html
# https://www.nttpc.co.jp//column/data_center/collocation.html
# https://www.nttpc.co.jp//column/security/ids-ips.html
# https://www.nttpc.co.jp//column/security/firewall.html
# https://www.nttpc.co.jp//column/security/sql_injection.html
# https://www.nttpc.co.jp//column/network/sase.html
# https://www.nttpc.co.jp//column/network/zero_trust.html
# https://www.nttpc.co.jp//column/security/cross_site_scripting.html
# https://www.nttpc.co.jp//column/security/waf.html
# https://www.nttpc.co.jp//column/security/cyber_attack.html
# https://www.nttpc.co.jp//column/security/security_measures.html
# https://www.nttpc.co.jp//column/security/unauthorized_access.html
# https://www.nttpc.co.jp//column/security/ransomware_defendmethod.html
# https://www.nttpc.co.jp//column/security/ransomware.html
# https://www.nttpc.co.jp//column/security/cloud_security.html
# https://www.nttpc.co.jp//column/security/malware.html
# https://www.nttpc.co.jp//column/security/vpn_security.html
# https://www.nttpc.co.jp//column/network/vpn_service.html
# https://www.nttpc.co.jp//column/network/ip_vpn.html
# https://www.nttpc.co.jp//column/network/bcp_measures.html
# https://www.nttpc.co.jp//column/telework/remote_access.html
# https://www.nttpc.co.jp//column/telework/sdwan_sdn.html
# https://www.nttpc.co.jp//column/network/whats_convergence.html
# https://www.nttpc.co.jp//column/network/o365_sdwan.html
# https://www.nttpc.co.jp//column/network/network_design.html
# https://www.nttpc.co.jp//column/network/whats_it_infrastructure.html
# https://www.nttpc.co.jp//column/network/whats_vpn.html
# https://www.nttpc.co.jp//column/network/whats_ip.html
# https://www.nttpc.co.jp//column/network/whats_bcp.html
# https://www.nttpc.co.jp//column/security/hacker.html
# https://www.nttpc.co.jp//column/security/vpn_security_risk.html
# https://www.nttpc.co.jp//column/network/cloudwan_5g.html
# https://www.nttpc.co.jp//column/network/leasedline.html
# https://www.nttpc.co.jp//column/network/internal_network.html
# https://www.nttpc.co.jp//column/data_center/data_center.html
# https://www.nttpc.co.jp//column/security/bof.html
# https://www.nttpc.co.jp//column/security/exploit.html
# https://www.nttpc.co.jp//column/security/epp-edr.html
# https://www.nttpc.co.jp//column/security/information_leakage_measures.html
# https://www.nttpc.co.jp//column/security/phishing-site.html
# https://www.nttpc.co.jp//column/network/fixed_ip.html
# https://www.nttpc.co.jp//column/network/pppoe_ipoe.html
# https://www.nttpc.co.jp//column/security/os-command_injection.html
# https://www.nttpc.co.jp//column/data_center/collocation.html
# https://www.nttpc.co.jp//column/security/ids-ips.html
# https://www.nttpc.co.jp//column/security/firewall.html
# https://www.nttpc.co.jp//column/security/sql_injection.html
# https://www.nttpc.co.jp//column/network/sase.html
# https://www.nttpc.co.jp//column/network/zero_trust.html
# https://www.nttpc.co.jp//column/security/cross_site_scripting.html
# https://www.nttpc.co.jp//column/security/waf.html
# https://www.nttpc.co.jp//column/security/cyber_attack.html
# https://www.nttpc.co.jp//column/security/security_measures.html
# https://www.nttpc.co.jp//column/security/unauthorized_access.html
# https://www.nttpc.co.jp//column/security/ransomware_defendmethod.html
# https://www.nttpc.co.jp//column/security/ransomware.html
# https://www.nttpc.co.jp//column/security/cloud_security.html
# https://www.nttpc.co.jp//column/security/malware.html
# https://www.nttpc.co.jp//column/security/vpn_security.html
# https://www.nttpc.co.jp//column/network/vpn_service.html
# https://www.nttpc.co.jp//column/network/ip_vpn.html
# https://www.nttpc.co.jp//column/network/bcp_measures.html
# https://www.nttpc.co.jp//column/telework/remote_access.html
# https://www.nttpc.co.jp//column/telework/sdwan_sdn.html
# https://www.nttpc.co.jp//column/network/whats_convergence.html
# https://www.nttpc.co.jp//column/network/o365_sdwan.html
# https://www.nttpc.co.jp//column/network/network_design.html
# https://www.nttpc.co.jp//column/network/whats_it_infrastructure.html
# https://www.nttpc.co.jp//column/network/whats_vpn.html
# https://www.nttpc.co.jp//column/network/whats_ip.html
# https://www.nttpc.co.jp//column/network/whats_bcp.html
# https://www.nttpc.co.jp//column/security/hacker.html
# https://www.nttpc.co.jp//column/security/vpn_security_risk.html
# https://www.nttpc.co.jp//column/network/cloudwan_5g.html
# https://www.nttpc.co.jp//column/network/leasedline.html
# https://www.nttpc.co.jp//column/network/internal_network.html
# https://www.nttpc.co.jp//column/data_center/data_center.html
# https://www.nttpc.co.jp//column/security/bof.html
# https://www.nttpc.co.jp//column/security/exploit.html
# https://www.nttpc.co.jp//column/security/epp-edr.html
# https://www.nttpc.co.jp//column/security/information_leakage_measures.html
# https://www.nttpc.co.jp//column/security/phishing-site.html
# https://www.nttpc.co.jp//column/network/fixed_ip.html
# https://www.nttpc.co.jp//column/network/pppoe_ipoe.html
# https://www.nttpc.co.jp//column/security/os-command_injection.html
# https://www.nttpc.co.jp//column/data_center/collocation.html
# https://www.nttpc.co.jp//column/security/ids-ips.html
# https://www.nttpc.co.jp//column/security/firewall.html
# https://www.nttpc.co.jp//column/security/sql_injection.html
# https://www.nttpc.co.jp//column/network/sase.html
# https://www.nttpc.co.jp//column/network/zero_trust.html
# https://www.nttpc.co.jp//column/security/cross_site_scripting.html
# https://www.nttpc.co.jp//column/security/waf.html
# https://www.nttpc.co.jp//column/security/cyber_attack.html
# https://www.nttpc.co.jp//column/security/security_measures.html
# https://www.nttpc.co.jp//column/security/unauthorized_access.html
# https://www.nttpc.co.jp//column/security/ransomware_defendmethod.html
# https://www.nttpc.co.jp//column/security/ransomware.html
# https://www.nttpc.co.jp//column/security/cloud_security.html
# https://www.nttpc.co.jp//column/security/malware.html
# https://www.nttpc.co.jp//column/security/vpn_security.html
# https://www.nttpc.co.jp//column/network/vpn_service.html
# https://www.nttpc.co.jp//column/network/ip_vpn.html
# https://www.nttpc.co.jp//column/network/bcp_measures.html
# https://www.nttpc.co.jp//column/telework/remote_access.html
# https://www.nttpc.co.jp//column/telework/sdwan_sdn.html
# https://www.nttpc.co.jp//column/network/whats_convergence.html
# https://www.nttpc.co.jp//column/network/o365_sdwan.html
# https://www.nttpc.co.jp//column/network/network_design.html
# https://www.nttpc.co.jp//column/network/whats_it_infrastructure.html
# https://www.nttpc.co.jp//column/network/whats_vpn.html
# https://www.nttpc.co.jp//column/network/whats_ip.html
# https://www.nttpc.co.jp//column/network/whats_bcp.html
# https://www.nttpc.co.jp//column/security/hacker.html
# https://www.nttpc.co.jp//column/security/vpn_security_risk.html
# https://www.nttpc.co.jp//column/network/cloudwan_5g.html
# https://www.nttpc.co.jp//column/network/leasedline.html
# https://www.nttpc.co.jp//column/network/internal_network.html
# https://www.nttpc.co.jp//column/data_center/data_center.html
# https://www.nttpc.co.jp//column/security/bof.html
# https://www.nttpc.co.jp//column/security/exploit.html
# https://www.nttpc.co.jp//column/security/epp-edr.html
# https://www.nttpc.co.jp//column/security/information_leakage_measures.html
# https://www.nttpc.co.jp//column/security/phishing-site.html
# https://www.nttpc.co.jp//column/network/fixed_ip.html
# https://www.nttpc.co.jp//column/network/pppoe_ipoe.html
# https://www.nttpc.co.jp//column/security/os-command_injection.html
# https://www.nttpc.co.jp//column/data_center/collocation.html
# https://www.nttpc.co.jp//column/security/ids-ips.html
# https://www.nttpc.co.jp//column/security/firewall.html
# https://www.nttpc.co.jp//column/security/sql_injection.html
# https://www.nttpc.co.jp//column/network/sase.html
# https://www.nttpc.co.jp//column/network/zero_trust.html
# https://www.nttpc.co.jp//column/security/cross_site_scripting.html
# https://www.nttpc.co.jp//column/security/waf.html
# https://www.nttpc.co.jp//column/security/cyber_attack.html
# https://www.nttpc.co.jp//column/security/security_measures.html
# https://www.nttpc.co.jp//column/security/unauthorized_access.html
# https://www.nttpc.co.jp//column/security/ransomware_defendmethod.html
# https://www.nttpc.co.jp//column/security/ransomware.html
# https://www.nttpc.co.jp//column/security/cloud_security.html
# https://www.nttpc.co.jp//column/security/malware.html
# https://www.nttpc.co.jp//column/security/vpn_security.html
# https://www.nttpc.co.jp//column/network/vpn_service.html
# https://www.nttpc.co.jp//column/network/ip_vpn.html
# https://www.nttpc.co.jp//column/network/bcp_measures.html
# https://www.nttpc.co.jp//column/telework/remote_access.html
# https://www.nttpc.co.jp//column/telework/sdwan_sdn.html
# https://www.nttpc.co.jp//column/network/whats_convergence.html
# https://www.nttpc.co.jp//column/network/o365_sdwan.html
# https://www.nttpc.co.jp//column/network/network_design.html
# https://www.nttpc.co.jp//column/network/whats_it_infrastructure.html
# https://www.nttpc.co.jp//column/network/whats_vpn.html
# https://www.nttpc.co.jp//column/network/whats_ip.html
# https://www.nttpc.co.jp//column/network/whats_bcp.html
# https://www.nttpc.co.jp//column/security/hacker.html
# https://www.nttpc.co.jp//column/security/vpn_security_risk.html
# https://www.nttpc.co.jp//column/network/cloudwan_5g.html
# https://www.nttpc.co.jp//column/network/leasedline.html
# https://www.nttpc.co.jp//column/network/internal_network.html
# https://www.nttpc.co.jp//column/data_center/data_center.html
# https://www.nttpc.co.jp//column/security/bof.html
# https://www.nttpc.co.jp//column/security/exploit.html
# https://www.nttpc.co.jp//column/security/epp-edr.html
# https://www.nttpc.co.jp//column/security/information_leakage_measures.html
# https://www.nttpc.co.jp//column/security/phishing-site.html
# https://www.nttpc.co.jp//column/network/fixed_ip.html
# https://www.nttpc.co.jp//column/network/pppoe_ipoe.html
# https://www.nttpc.co.jp//column/security/os-command_injection.html
# https://www.nttpc.co.jp//column/data_center/collocation.html
# https://www.nttpc.co.jp//column/security/ids-ips.html
# https://www.nttpc.co.jp//column/security/firewall.html
# https://www.nttpc.co.jp//column/security/sql_injection.html
# https://www.nttpc.co.jp//column/network/sase.html
# https://www.nttpc.co.jp//column/network/zero_trust.html
# https://www.nttpc.co.jp//column/security/cross_site_scripting.html
# https://www.nttpc.co.jp//column/security/waf.html
# https://www.nttpc.co.jp//column/security/cyber_attack.html
# https://www.nttpc.co.jp//column/security/security_measures.html
# https://www.nttpc.co.jp//column/security/unauthorized_access.html
# https://www.nttpc.co.jp//column/security/ransomware_defendmethod.html
# https://www.nttpc.co.jp//column/security/ransomware.html
# https://www.nttpc.co.jp//column/security/cloud_security.html
# https://www.nttpc.co.jp//column/security/malware.html
# https://www.nttpc.co.jp//column/security/vpn_security.html
# https://www.nttpc.co.jp//column/network/vpn_service.html
# https://www.nttpc.co.jp//column/network/ip_vpn.html
# https://www.nttpc.co.jp//column/network/bcp_measures.html
# https://www.nttpc.co.jp//column/telework/remote_access.html
# https://www.nttpc.co.jp//column/telework/sdwan_sdn.html
# https://www.nttpc.co.jp//column/network/whats_convergence.html
# https://www.nttpc.co.jp//column/network/o365_sdwan.html
# https://www.nttpc.co.jp//column/network/network_design.html
# https://www.nttpc.co.jp//column/network/whats_it_infrastructure.html
# Links Saved in links/nttpc.txt
# True
