# %% [markdown]
# ### Scraper for <a href="https://www.eiyokentei.com/category/column/"> Eiyokentei </a> website

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import os
import requests

# %%
def get_chrome_Driver():
    driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
    return driver

def get_soup(URL):
    r = requests.get(URL)
    if r:
        driver = get_chrome_Driver()
        driver.get(URL)
        htmlContent = driver.page_source
        soup =  BeautifulSoup(htmlContent, 'html.parser')
        driver.close()
        return soup
    else:
        print("Error Fetching Soup, Scraping Ended")
        return False

def get_link_from_soup(soup):
    wanted_div = soup.findAll('div', {'class':'list ect-vertical-card-2 ect-vertical-card ect-2-columns front-page-type-index'})[0]
    links= wanted_div.findAll('a', {'class':'entry-card-wrap a-wrap border-element cf'})
    link_list = []

    for link in links:
        link = str(link['href'])
        print(link)
        link_list.append(link)

    return link_list



def save_link_as_txt(link_list):
    file_path = "links/bb-navi.txt"
    # if file exist, get its content, merge to existing set and then overwrite
    if os.path.isfile(file_path):
        with open(file_path, 'r+', encoding="utf-8") as file:
            # get existing links in file
            old_links = set(file.readlines())
            # remove duplicates 
            link_list = link_list - old_links
            file.seek(0)
            for i in link_list:
                file.write(i+"\n")
            file.truncate()
    else: # if not, make new file
        os.makedirs(os.path.dirname(file_path), exist_ok=True)
        with open(file_path, "w", encoding="utf-8") as file:
            for i in link_list:
                file.write(i+"\n")
    print(f"Links Saved in {file_path}")
    return True

# %%
all_links = set()
for i in range(1,10):
    soup = get_soup(f"https://bb-navi.jp/column/category/wifi/page/{i}/")
    if soup:
        current_links = get_link_from_soup(soup)
        if len(current_links) > 0: # continue until no tags are found 
            all_links.update(current_links)
        else: # if tags we want are not found
            break
    else: # if encountered HTML error such as 404
        break

save_link_as_txt(all_links)
# Out:
# https://bb-navi.jp/column/%e6%88%b8%e5%bb%ba%e3%81%a6%e3%81%a7%e4%b8%80%e7%95%aa%e9%80%9f%e5%ba%a6%e3%81%ae%e9%80%9f%e3%81%84%e5%85%89%e5%9b%9e%e7%b7%9a%e3%81%af%ef%bc%9f/
# https://bb-navi.jp/column/mobarecoair-softbankair-difference0422
# https://bb-navi.jp/column/amazon-prime-video-tv1030
# https://bb-navi.jp/column/work-remotely-wifi0929
# https://bb-navi.jp/column/amazon-prime-video-internet-line-speed0909
# https://bb-navi.jp/column/uqmobile-set-discount-internet-line0907
# https://bb-navi.jp/column/docomo-home5g-optical-line-comparison1025
# https://bb-navi.jp/column/wi-fi%e3%81%8c%e9%81%85%e3%81%84%e7%b9%8b%e3%81%8c%e3%82%89%e3%81%aa%e3%81%84%e5%8e%9f%e5%9b%a0%e3%81%a8%e5%af%be%e7%ad%96%e3%82%92%e5%88%86%e6%9e%90/
# https://bb-navi.jp/column/optical-line-wifi-difference0912
# https://bb-navi.jp/column/linemo-softbankhikari-set-discount0918
# https://bb-navi.jp/column/internet-line-campaign1130
# https://bb-navi.jp/column/salon-wifi/
# https://bb-navi.jp/column/hikari-collabo-recomended1224
# https://bb-navi.jp/column/free-wifi-end-measures0713
# https://bb-navi.jp/column/new-house-internet-line0913
# https://bb-navi.jp/column/opticalline-homerouter-comparison0120
# https://bb-navi.jp/column/softbankair-optical-line-comparison0119
# https://bb-navi.jp/column/softbankair-rakuten-mobile-comparison0131
# https://bb-navi.jp/column/adsl-end-change0711
# https://bb-navi.jp/column/smartphone-fixed-line-wifi0131
# https://bb-navi.jp/column/provider-campaign1215
# https://bb-navi.jp/column/ocnhikari-ocnfordocomo0710
# https://bb-navi.jp/column/no-construction-required-unlimited-internet0110
# https://bb-navi.jp/column/home-employment-internet-line0201
# https://bb-navi.jp/column/%e3%83%97%e3%83%ad%e3%83%90%e3%82%a4%e3%83%80%e9%81%b8%e3%81%b3%e3%81%a7%e5%a4%b1%e6%95%97%e3%81%97%e3%81%aa%e3%81%84%e6%96%b9%e6%b3%95%e3%81%af_%e4%b9%97%e3%82%8a%e6%8f%9b%e3%81%88%e6%99%82%e3%81%ae/
# https://bb-navi.jp/column/two-family-house-wifi0621
# https://bb-navi.jp/column/share-house-internet-line-recommendation0613
# https://bb-navi.jp/column/restaurant-optical-line0109
# https://bb-navi.jp/column/wifi-internet-trouble-solutions1129
# https://bb-navi.jp/column/kominka-hotel1208
# https://bb-navi.jp/column/sumaho-sokudo/
# https://bb-navi.jp/column/home-internet-line-recommendation0523
# https://bb-navi.jp/column/couple-recommendation-wifi0522
# https://bb-navi.jp/column/optical-line-apartment0516
# https://bb-navi.jp/column/no-phone-line-internet-contract0511
# https://bb-navi.jp/column/family-of-5-communication-costs-savings0508
# https://bb-navi.jp/column/internet-cheapest-apartment1007
# https://bb-navi.jp/column/only-plug-in-the-outlet-wifi0502
# https://bb-navi.jp/column/homerouter-comparison0429
# https://bb-navi.jp/column/au-sumaho-savings0429
# https://bb-navi.jp/column/softbank-sumaho-savings0427
# https://bb-navi.jp/column/family-of-four-savings-communication-costs0422
# https://bb-navi.jp/column/detached-house-internet-contract0930
# https://bb-navi.jp/column/pocket-wifi-recommendation-living-alone0416
# https://bb-navi.jp/column/internet-environment-recommendation0416
# https://bb-navi.jp/column/cheep-wifi-living-alone0416
# https://bb-navi.jp/column/internet-line-family-of-3-0412
# https://bb-navi.jp/column/data-it/
# https://bb-navi.jp/column/flets-wifi/
# https://bb-navi.jp/column/use-the-internet-immediately0904
# https://bb-navi.jp/column/libmo-set-optical-line0404
# https://bb-navi.jp/column/living-alone-internet-line-kinds0402
# https://bb-navi.jp/column/university-student-recommendation-communication-service0327
# https://bb-navi.jp/column/no-minimum-usage-period-internet1119
# https://bb-navi.jp/column/%e8%87%aa%e5%ae%85%e3%81%ae%e3%81%8a%e3%81%99%e3%81%99%e3%82%81wi-fi%e3%81%af%ef%bc%9f%e3%82%b9%e3%83%9e%e3%83%9b%e3%81%a8%e4%b8%80%e7%b7%92%e3%81%ab%e4%bd%bf%e3%81%88%e3%82%8b%e5%85%89%e5%9b%9e/
# https://bb-navi.jp/column/optical-line-wifi-home0712
# https://bb-navi.jp/column/ones-home-wifi-unlimited0310
# https://bb-navi.jp/column/new-life-recommendation-wifi0310
# https://bb-navi.jp/column/net-fee/
# https://bb-navi.jp/column/telework/
# https://bb-navi.jp/column/wi-fi-speed-slow0302
# https://bb-navi.jp/column/optical-line-mobile-line-comparison0228
# https://bb-navi.jp/column/zoom-recomendede-internet-line0225
# https://bb-navi.jp/column/osaka-recomended-internet-line0224
# https://bb-navi.jp/column/povo-auhikari-set-discount0918
# https://bb-navi.jp/column/gigaraku/
# https://bb-navi.jp/column/how-to-apply-optical-line0213
# https://bb-navi.jp/column/internet-communication-costs-savings0213
# https://bb-navi.jp/column/tokyo-recomended-internet-line0210
# https://bb-navi.jp/column/freelance-recomended-cheep-wifi0210
# https://bb-navi.jp/column/optical-line-wireless-speed-up0207
# https://bb-navi.jp/column/how-to-use-docomo-line-unlimited0207
# https://bb-navi.jp/column/how-to-use-optical-line-housing-complex0205
# https://bb-navi.jp/column/hikari-collabo-how-to-change0205
# https://bb-navi.jp/column/internet-speed-how-to-make-it-faster0202
# https://bb-navi.jp/column/fletshikari-transfer-method0201
# https://bb-navi.jp/column/internet-speed-rough-indication0201
# https://bb-navi.jp/column/online-class-preparation0125
# https://bb-navi.jp/column/shop_net/
# https://bb-navi.jp/column/internet-not-connect1210
# https://bb-navi.jp/column/internet-price-comparison-by-use1129
# https://bb-navi.jp/column/ymobile-optical-line-set0907
# Links Saved in links/bb-navi.txt
# True
