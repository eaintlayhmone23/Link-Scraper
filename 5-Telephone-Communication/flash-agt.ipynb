# %% [markdown]
# ### Scraper for <a href="https://www.eiyokentei.com/category/column/"> Eiyokentei </a> website

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import os
import requests

# %%
def get_chrome_Driver():
    driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
    return driver

def get_soup(URL):
    r = requests.get(URL)
    if r:
        driver = get_chrome_Driver()
        driver.get(URL)
        htmlContent = driver.page_source
        soup =  BeautifulSoup(htmlContent, 'html.parser')
        driver.close()
        return soup
    else:
        print("Error Fetching Soup, Scraping Ended")
        return False

def get_link_from_soup(soup):
    ul = soup.findAll('ul', {'class':'bloglist'})[0]
    wanted_lis = ul.findAll('li')
       
    link_list = []

    for li in wanted_lis:
        link =  li.find('section').div.div.a
        link = str(link['href'])
        print('link',link)
        link_list.append(link)
        
    return link_list



def save_link_as_txt(link_list):
    file_path = "links/flash-agt.txt"
    # if file exist, get its content, merge to existing set and then overwrite
    if os.path.isfile(file_path):
        with open(file_path, 'r+', encoding="utf-8") as file:
            # get existing links in file
            old_links = set(file.readlines())
            # remove duplicates 
            link_list = link_list - old_links
            file.seek(0)
            for i in link_list:
                file.write(i+"\n")
            file.truncate()
    else: # if not, make new file
        os.makedirs(os.path.dirname(file_path), exist_ok=True)
        with open(file_path, "w", encoding="utf-8") as file:
            for i in link_list:
                file.write(i+"\n")
    print(f"Links Saved in {file_path}")
    return True

# %%
all_links = set()
for i in range(1,29):
    if i == 1:
        URL = 'https://flash-agt.com/blog/tips'
    else:
        URL = f"https://flash-agt.com/blog/tips?page={i}"
    
    soup = get_soup(URL)
    if soup:
        current_links = get_link_from_soup(soup)
        if len(current_links) > 0: # continue until no tags are found 
            all_links.update(current_links)
        else: # if tags we want are not found
            break
    else: # if encountered HTML error such as 404
        break

save_link_as_txt(all_links)
# Out:
# link https://flash-agt.com/blog/tips/52769
# link https://flash-agt.com/blog/tips/54133
# link https://flash-agt.com/blog/tips/54126
# link https://flash-agt.com/blog/tips/54118
# link https://flash-agt.com/blog/tips/54112
# link https://flash-agt.com/blog/tips/54106
# link https://flash-agt.com/blog/tips/54096
# link https://flash-agt.com/blog/tips/54086
# link https://flash-agt.com/blog/tips/54076
# link https://flash-agt.com/blog/tips/54066
# link https://flash-agt.com/blog/tips/54017
# link https://flash-agt.com/blog/tips/54011
# link https://flash-agt.com/blog/tips/53990
# link https://flash-agt.com/blog/tips/53989
# link https://flash-agt.com/blog/tips/53988
# link https://flash-agt.com/blog/tips/53987
# link https://flash-agt.com/blog/tips/53986
# link https://flash-agt.com/blog/tips/53889
# link https://flash-agt.com/blog/tips/53881
# link https://flash-agt.com/blog/tips/53860
# link https://flash-agt.com/blog/tips/53852
# link https://flash-agt.com/blog/tips/53844
# link https://flash-agt.com/blog/tips/53732
# link https://flash-agt.com/blog/tips/53800
# link https://flash-agt.com/blog/tips/53799
# link https://flash-agt.com/blog/tips/53798
# link https://flash-agt.com/blog/tips/53797
# link https://flash-agt.com/blog/tips/53833
# link https://flash-agt.com/blog/tips/53821
# link https://flash-agt.com/blog/tips/53782
# link https://flash-agt.com/blog/tips/53774
# link https://flash-agt.com/blog/tips/53674
# link https://flash-agt.com/blog/tips/53716
# link https://flash-agt.com/blog/tips/53636
# link https://flash-agt.com/blog/tips/53548
# link https://flash-agt.com/blog/tips/53524
# link https://flash-agt.com/blog/tips/53516
# link https://flash-agt.com/blog/tips/53456
# link https://flash-agt.com/blog/tips/53595
# link https://flash-agt.com/blog/tips/53600
